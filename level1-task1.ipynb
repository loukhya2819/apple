# %% [markdown]
# <a href="https://colab.research.google.com/github/loukhya2819/apple/blob/main/level1-task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - Level 1: Student Score Analysis

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("/student_scores.csv")

# Show first 5 records
print("🔹 First 5 Records:")
print(df.head())

# Basic info
print("\n🔹 Dataset Info:")
print(df.info())

# Descriptive statistics
print("\n🔹 Descriptive Statistics:")
print(df.describe())

# Check for missing values
print("\n🔹 Missing Values:")
print(df.isnull().sum())

# Correlation heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(df.drop("Name", axis=1).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Subjects & Attendance")
plt.show()

# Plot subject-wise scores
plt.figure(figsize=(10, 5))
df.drop("Name", axis=1).plot(kind="box")
plt.title("Score Distribution per Subject")
plt.ylabel("Marks")
plt.grid(True)
plt.show()
# Out:
# 🔹 First 5 Records:
#      Name  Math  Science  English  Attendance
# 0   Arjun    78       85       69          92
# 1    Riya    88       79       94          98
# 2   Kabir    56       62       70          80
# 3  Ananya    90       95       93         100
# 4   Meera    67       72       60          75
#
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Math        10 non-null     int64
#  2   Science     10 non-null     int64
#  3   English     10 non-null     int64
#  4   Attendance  10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes
# None
#
# 🔹 Descriptive Statistics:
#             Math    Science   English  Attendance
# count  10.000000  10.000000  10.00000   10.000000
# mean   73.800000  77.000000  76.40000   86.600000
# ...
